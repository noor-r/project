# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1389, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# 20  2020-12-13  16:30  Premier League  Matchweek 12  Sun  Away      D  1.0
# 21  2020-12-16  20:00  Premier League  Matchweek 13  Wed  Home      W  2.0
# 22  2020-12-19  12:30  Premier League  Matchweek 14  Sat  Away      W  7.0
# 23  2020-12-27  16:30  Premier League  Matchweek 15  Sun  Home      D  1.0
# 24  2020-12-30  20:00  Premier League  Matchweek 16  Wed  Away      D  0.0
# 25  2021-01-04  20:00  Premier League  Matchweek 17  Mon  Away      L  0.0
# 27  2021-01-17  16:30  Premier League  Matchweek 19  Sun  Home      D  0.0
# 28  2021-01-21  20:00  Premier League  Matchweek 18  Thu  Home      L  0.0
# 30  2021-01-28  20:00  Premier League  Matchweek 20  Thu  Away      W  3.0
# 31  2021-01-31  16:30  Premier League  Matchweek 21  Sun  Away      W  3.0
# 32  2021-02-03  20:15  Premier League  Matchweek 22  Wed  Home      L  0.0
# 33  2021-02-07  16:30  Premier League  Matchweek 23  Sun  Home      L  1.0
# 34  2021-02-13  12:30  Premier League  Matchweek 24  Sat  Away      L  1.0
# 36  2021-02-20  17:30  Premier League  Matchweek 25  Sat  Home      L  0.0
# 37  2021-02-28  19:15  Premier League  Matchweek 26  Sun  Away      W  2.0
# 38  2021-03-04  20:15  Premier League  Matchweek 29  Thu  Home      L  0.0
# 39  2021-03-07  14:00  Premier League  Matchweek 27  Sun  Home      L  0.0
# 41  2021-03-15  20:00  Premier League  Matchweek 28  Mon  Away      W  1.0
# 42  2021-04-03  20:00  Premier League  Matchweek 30  Sat  Away      W  3.0
# 44  2021-04-10  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 46  2021-04-19  20:00  Premier League  Matchweek 32  Mon  Away      D  1.0
# 47  2021-04-24  12:30  Premier League  Matchweek 33  Sat  Home      D  1.0
# 48  2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W  2.0
# 49  2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W  4.0
# 50  2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W  2.0
# 51  2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W  3.0
# 52  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# 1   3.0     Leeds United  ...  Match Report    NaN  20.0   4.0  17.0  0.0
# 2   0.0          Chelsea  ...  Match Report    NaN  17.0   5.0  17.7  1.0
# 4   1.0          Arsenal  ...  Match Report    NaN  21.0   9.0  16.8  0.0
# 6   7.0      Aston Villa  ...  Match Report    NaN  14.0   8.0  15.8  1.0
# 7   2.0          Everton  ...  Match Report    NaN  22.0   8.0  15.0  1.0
# 9   1.0    Sheffield Utd  ...  Match Report    NaN  17.0   5.0  18.2  1.0
# 11  1.0         West Ham  ...  Match Report    NaN   8.0   2.0  18.6  1.0
# 13  1.0  Manchester City  ...  Match Report    NaN   9.0   2.0  21.5  0.0
# 14  0.0   Leicester City  ...  Match Report    NaN  24.0  12.0  11.9  0.0
# 16  1.0         Brighton  ...  Match Report    NaN   6.0   2.0  20.9  0.0
# 18  0.0           Wolves  ...  Match Report    NaN  11.0   6.0  16.6  1.0
# 20  1.0           Fulham  ...  Match Report    NaN  11.0   5.0  20.0  1.0
# 21  1.0        Tottenham  ...  Match Report    NaN  17.0  11.0  15.5  0.0
# 22  0.0   Crystal Palace  ...  Match Report    NaN  14.0   7.0  13.2  1.0
# 23  1.0        West Brom  ...  Match Report    NaN  17.0   2.0  17.8  2.0
# 24  0.0    Newcastle Utd  ...  Match Report    NaN  11.0   4.0  16.7  0.0
# 25  1.0      Southampton  ...  Match Report    NaN  17.0   1.0  14.3  0.0
# 27  0.0   Manchester Utd  ...  Match Report    NaN  17.0   3.0  17.1  0.0
# 28  1.0          Burnley  ...  Match Report    NaN  27.0   6.0  17.3  0.0
# 30  1.0        Tottenham  ...  Match Report    NaN  14.0   7.0  14.7  0.0
# 31  1.0         West Ham  ...  Match Report    NaN  14.0   5.0  15.3  0.0
# 32  1.0         Brighton  ...  Match Report    NaN  11.0   0.0  19.9  0.0
# 33  4.0  Manchester City  ...  Match Report    NaN   7.0   2.0  17.9  1.0
# 34  3.0   Leicester City  ...  Match Report    NaN  15.0   4.0  15.4  2.0
# 36  2.0          Everton  ...  Match Report    NaN  16.0   6.0  15.9  1.0
# 37  0.0    Sheffield Utd  ...  Match Report    NaN  15.0   8.0  14.2  0.0
# 38  1.0          Chelsea  ...  Match Report    NaN   7.0   1.0  18.4  0.0
# 39  1.0           Fulham  ...  Match Report    NaN  16.0   3.0  17.0  1.0
# 41  0.0           Wolves  ...  Match Report    NaN  12.0   4.0  15.9  0.0
# 42  0.0          Arsenal  ...  Match Report    NaN  16.0   7.0  17.0  0.0
# 44  1.0      Aston Villa  ...  Match Report    NaN  23.0   8.0  16.7  1.0
# 46  1.0     Leeds United  ...  Match Report    NaN  17.0   7.0  15.7  0.0
# 47  1.0    Newcastle Utd  ...  Match Report    NaN  21.0   9.0  17.0  1.0
# 48  0.0      Southampton  ...  Match Report    NaN  14.0   6.0  12.4  0.0
# 49  2.0   Manchester Utd  ...  Match Report    NaN  17.0   8.0  14.9  0.0
# 50  1.0        West Brom  ...  Match Report    NaN  26.0   6.0  16.9  1.0
# 51  0.0          Burnley  ...  Match Report    NaN  20.0   3.0  15.5  1.0
# 52  0.0   Crystal Palace  ...  Match Report    NaN  19.0   5.0  14.2  1.0
#
#      pk pkatt  season       team
# 1   2.0   2.0    2021  Liverpool
# 2   0.0   0.0    2021  Liverpool
# 4   0.0   0.0    2021  Liverpool
# 6   0.0   0.0    2021  Liverpool
# 7   0.0   0.0    2021  Liverpool
# 9   0.0   0.0    2021  Liverpool
# 11  1.0   1.0    2021  Liverpool
# 13  1.0   1.0    2021  Liverpool
# 14  0.0   0.0    2021  Liverpool
# 16  0.0   0.0    2021  Liverpool
# 18  0.0   0.0    2021  Liverpool
# 20  1.0   1.0    2021  Liverpool
# 21  0.0   0.0    2021  Liverpool
# 22  0.0   0.0    2021  Liverpool
# 23  0.0   0.0    2021  Liverpool
# 24  0.0   0.0    2021  Liverpool
# 25  0.0   0.0    2021  Liverpool
# 27  0.0   0.0    2021  Liverpool
# 28  0.0   0.0    2021  Liverpool
# 30  0.0   0.0    2021  Liverpool
# 31  0.0   0.0    2021  Liverpool
# 32  0.0   0.0    2021  Liverpool
# 33  1.0   1.0    2021  Liverpool
# 34  0.0   0.0    2021  Liverpool
# 36  0.0   0.0    2021  Liverpool
# 37  0.0   0.0    2021  Liverpool
# 38  0.0   0.0    2021  Liverpool
# 39  0.0   0.0    2021  Liverpool
# 41  0.0   0.0    2021  Liverpool
# 42  0.0   0.0    2021  Liverpool
# 44  0.0   0.0    2021  Liverpool
# 46  0.0   0.0    2021  Liverpool
# 47  0.0   0.0    2021  Liverpool
# 48  0.0   0.0    2021  Liverpool
# 49  0.0   0.0    2021  Liverpool
# 50  0.0   0.0    2021  Liverpool
# 51  0.0   0.0    2021  Liverpool
# 52  0.0   0.0    2021  Liverpool
#
# [38 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...  match report    sh   sot  dist   fk   pk pkatt  \
# 1        Tottenham  1.9  ...  Match Report  18.0   4.0  16.9  1.0  0.0   0.0
# 2     Norwich City  2.7  ...  Match Report  16.0   4.0  17.3  1.0  0.0   0.0
# 3          Arsenal  3.8  ...  Match Report  25.0  10.0  14.3  0.0  0.0   0.0
# 4   Leicester City  2.9  ...  Match Report  25.0   8.0  14.0  0.0  0.0   0.0
# 6      Southampton  1.1  ...  Match Report  16.0   1.0  15.7  1.0  0.0   0.0
# ..             ...  ...  ...           ...   ...   ...   ...  ...  ...   ...
# 38       Tottenham  0.5  ...  Match Report   8.0   1.0  17.4  0.0  0.0   0.0
# 39  Crystal Palace  0.7  ...  Match Report   7.0   0.0  11.4  1.0  0.0   0.0
# 40         Everton  1.6  ...  Match Report  10.0   3.0  17.0  0.0  0.0   0.0
# 41   Newcastle Utd  0.8  ...  Match Report  11.0   1.0  16.0  1.0  0.0   0.0
# 42         Burnley  0.6  ...  Match Report  12.0   3.0  17.0  0.0  0.0   0.0
#
#     season              team  target
# 1     2022   Manchester City       0
# 2     2022   Manchester City       1
# 3     2022   Manchester City       1
# 4     2022   Manchester City       1
# 6     2022   Manchester City       0
# ..     ...               ...     ...
# 38    2021  Sheffield United       0
# 39    2021  Sheffield United       0
# 40    2021  Sheffield United       1
# 41    2021  Sheffield United       0
# 42    2021  Sheffield United       1
#
# [1389 rows x 26 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...   fk   pk  pkatt season              team target  \
# 1        Tottenham  1.9  ...  1.0  0.0    0.0   2022   Manchester City      0
# 2     Norwich City  2.7  ...  1.0  0.0    0.0   2022   Manchester City      1
# 3          Arsenal  3.8  ...  0.0  0.0    0.0   2022   Manchester City      1
# 4   Leicester City  2.9  ...  0.0  0.0    0.0   2022   Manchester City      1
# 6      Southampton  1.1  ...  1.0  0.0    0.0   2022   Manchester City      0
# ..             ...  ...  ...  ...  ...    ...    ...               ...    ...
# 38       Tottenham  0.5  ...  0.0  0.0    0.0   2021  Sheffield United      0
# 39  Crystal Palace  0.7  ...  1.0  0.0    0.0   2021  Sheffield United      0
# 40         Everton  1.6  ...  0.0  0.0    0.0   2021  Sheffield United      1
# 41   Newcastle Utd  0.8  ...  1.0  0.0    0.0   2021  Sheffield United      0
# 42         Burnley  0.6  ...  0.0  0.0    0.0   2021  Sheffield United      1
#
#    venue_code  opp_code  hour  day_code
# 1           0        18    16         6
# 2           1        15    15         5
# 3           1         0    12         5
# 4           0        10    15         5
# 6           1        17    15         5
# ..        ...       ...   ...       ...
# 38          0        18    19         6
# 39          1         6    15         5
# 40          0         7    19         6
# 41          0        14    18         2
# 42          1         4    16         6
#
# [1389 rows x 30 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-11-01']

# %%
test = matches[matches["date"] > '2022-09-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 preds = rf.predict(test[predictors])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1085     n_samples = _num_samples(array)
#    1086     if n_samples < ensure_min_samples:
# -> 1087         raise ValueError(
#    1088             "Found array with %d sample(s) (shape=%s) while a"
#    1089             " minimum of %d is required%s."
#    1090             % (n_samples, array.shape, ensure_min_samples, context)
#    1091         )
#    1093 if ensure_min_features > 0 and array.ndim == 2:
#    1094     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 4)) while a minimum of 1 is required by RandomForestClassifier.

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.7105263157894737

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1
# actual
# 0          81  13
# 1          31  27

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.675

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 3  2017-09-09  12:30   Matchweek 4  Sat  Home      W  5.0  0.0
# 5  2017-09-16  15:00   Matchweek 5  Sat  Away      W  6.0  0.0
# 7  2017-09-23  15:00   Matchweek 6  Sat  Home      W  5.0  0.0
# 9  2017-09-30  17:30   Matchweek 7  Sat  Away      W  1.0  0.0
# 10 2017-10-14  15:00   Matchweek 8  Sat  Home      W  7.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 10 2022-10-02  14:00   Matchweek 9  Sun  Home      W  6.0  3.0
# 12 2022-10-08  15:00  Matchweek 10  Sat  Home      W  4.0  0.0
# 14 2022-10-16  16:30  Matchweek 11  Sun  Away      L  0.0  1.0
# 15 2022-10-22  15:00  Matchweek 13  Sat  Home      W  3.0  1.0
# 17 2022-10-29  12:30  Matchweek 14  Sat  Away      W  1.0  0.0
#
#           opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 3        Liverpool  2.4  ...    12         5    1.666667   0.666667
# 5          Watford  3.3  ...    15         5    2.666667   0.666667
# 7   Crystal Palace  4.5  ...    15         5    4.333333   0.333333
# 9          Chelsea  0.9  ...    17         5    5.333333   0.000000
# 10      Stoke City  3.8  ...    15         5    4.000000   0.000000
# ..             ...  ...  ...   ...       ...         ...        ...
# 10  Manchester Utd  3.2  ...    14         6    3.333333   0.333333
# 12     Southampton  2.4  ...    15         5    3.333333   1.333333
# 14       Liverpool  1.0  ...    16         6    4.333333   1.000000
# 15        Brighton  1.6  ...    15         5    3.333333   1.333333
# 17  Leicester City  1.0  ...    12         5    2.333333   0.666667
#
#    sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 3   17.333333    6.000000    18.566667    1.333333    0.000000       0.000000
# 5   17.000000    8.000000    16.733333    0.666667    0.000000       0.000000
# 7   19.666667    9.000000    15.800000    0.333333    0.333333       0.333333
# 9   21.666667    9.333333    14.900000    0.000000    0.333333       0.333333
# 10  23.000000    7.666667    16.233333    0.333333    0.333333       0.333333
# ..        ...         ...          ...         ...         ...            ...
# 10  15.333333    6.666667    17.000000    0.333333    0.000000       0.000000
# 12  17.000000    6.666667    16.800000    0.666667    0.000000       0.000000
# 14  19.666667    8.000000    15.833333    0.333333    0.000000       0.000000
# 15  19.666667    7.666667    15.500000    0.333333    0.000000       0.000000
# 17  15.333333    5.666667    15.766667    0.000000    0.333333       0.333333
#
# [199 rows x 38 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 4  2017-09-09  15:00   Matchweek 4  Sat  Home      W
#                         6  2017-09-17  13:30   Matchweek 5  Sun  Away      D
#                         8  2017-09-25  20:00   Matchweek 6  Mon  Home      W
#                         10 2017-10-01  12:00   Matchweek 7  Sun  Home      W
#                         11 2017-10-14  17:30   Matchweek 8  Sat  Away      L
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 9  2022-10-08  15:00  Matchweek 10  Sat  Away      L
#                         10 2022-10-15  15:00  Matchweek 11  Sat  Home      W
#                         11 2022-10-18  20:15  Matchweek 12  Tue  Away      L
#                         12 2022-10-23  14:00  Matchweek 13  Sun  Home      L
#                         13 2022-10-29  15:00  Matchweek 14  Sat  Away      D
#
#                              gf   ga         opponent   xg  ...  hour  \
# team                                                        ...
# Arsenal                 4   3.0  0.0      Bournemouth  2.2  ...    15
#                         6   0.0  0.0          Chelsea  1.4  ...    13
#                         8   2.0  0.0        West Brom  2.2  ...    20
#                         10  2.0  0.0         Brighton  2.4  ...    12
#                         11  1.0  2.0          Watford  1.0  ...    17
# ...                         ...  ...              ...  ...  ...   ...
# Wolverhampton Wanderers 9   0.0  3.0          Chelsea  1.1  ...    15
#                         10  1.0  0.0  Nott'ham Forest  1.3  ...    15
#                         11  1.0  2.0   Crystal Palace  0.8  ...    20
#                         12  0.0  4.0   Leicester City  2.1  ...    14
#                         13  1.0  1.0        Brentford  0.6  ...    15
#
#                             day_code  gf_rolling ga_rolling sh_rolling  \
# team
# Arsenal                 4          5    1.333333   2.666667  17.666667
#                         6          6    1.000000   1.666667  14.333333
#                         8          0    1.000000   1.333333  12.000000
#                         10         6    1.666667   0.000000  14.333333
#                         11         5    1.333333   0.000000  17.000000
# ...                              ...         ...        ...        ...
# Wolverhampton Wanderers 9          5    0.333333   1.666667   9.333333
#                         10         5    0.000000   2.666667   9.666667
#                         11         1    0.333333   1.666667  10.333333
#                         12         6    0.666667   1.666667   8.666667
#                         13         5    0.666667   2.000000  13.000000
#
#                            sot_rolling dist_rolling  fk_rolling  pk_rolling  \
# team
# Arsenal                 4     5.333333    18.133333    0.000000    0.000000
#                         6     5.000000    16.766667    0.333333    0.000000
#                         8     3.666667    16.566667    0.333333    0.000000
#                         10    5.333333    17.400000    1.333333    0.333333
#                         11    5.000000    18.333333    1.666667    0.333333
# ...                                ...          ...         ...         ...
# Wolverhampton Wanderers 9     2.333333    18.033333    0.666667    0.000000
#                         10    2.333333    18.566667    1.000000    0.000000
#                         11    2.333333    17.633333    0.333333    0.333333
#                         12    2.333333    15.866667    0.666667    0.333333
#                         13    3.333333    16.266667    0.666667    0.333333
#
#                             pkatt_rolling
# team
# Arsenal                 4        0.000000
#                         6        0.000000
#                         8        0.000000
#                         10       0.333333
#                         11       0.333333
# ...                                   ...
# Wolverhampton Wanderers 9        0.000000
#                         10       0.000000
#                         11       0.333333
#                         12       0.333333
#                         13       0.333333
#
# [3956 rows x 38 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga  \
# 4  2017-09-09  15:00   Matchweek 4  Sat  Home      W  3.0  0.0
# 6  2017-09-17  13:30   Matchweek 5  Sun  Away      D  0.0  0.0
# 8  2017-09-25  20:00   Matchweek 6  Mon  Home      W  2.0  0.0
# 10 2017-10-01  12:00   Matchweek 7  Sun  Home      W  2.0  0.0
# 11 2017-10-14  17:30   Matchweek 8  Sat  Away      L  1.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 9  2022-10-08  15:00  Matchweek 10  Sat  Away      L  0.0  3.0
# 10 2022-10-15  15:00  Matchweek 11  Sat  Home      W  1.0  0.0
# 11 2022-10-18  20:15  Matchweek 12  Tue  Away      L  1.0  2.0
# 12 2022-10-23  14:00  Matchweek 13  Sun  Home      L  0.0  4.0
# 13 2022-10-29  15:00  Matchweek 14  Sat  Away      D  1.0  1.0
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 4       Bournemouth  2.2  ...    15         5    1.333333   2.666667
# 6           Chelsea  1.4  ...    13         6    1.000000   1.666667
# 8         West Brom  2.2  ...    20         0    1.000000   1.333333
# 10         Brighton  2.4  ...    12         6    1.666667   0.000000
# 11          Watford  1.0  ...    17         5    1.333333   0.000000
# ..              ...  ...  ...   ...       ...         ...        ...
# 9           Chelsea  1.1  ...    15         5    0.333333   1.666667
# 10  Nott'ham Forest  1.3  ...    15         5    0.000000   2.666667
# 11   Crystal Palace  0.8  ...    20         1    0.333333   1.666667
# 12   Leicester City  2.1  ...    14         6    0.666667   1.666667
# 13        Brentford  0.6  ...    15         5    0.666667   2.000000
#
#    sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 4   17.666667    5.333333    18.133333    0.000000    0.000000       0.000000
# 6   14.333333    5.000000    16.766667    0.333333    0.000000       0.000000
# 8   12.000000    3.666667    16.566667    0.333333    0.000000       0.000000
# 10  14.333333    5.333333    17.400000    1.333333    0.333333       0.333333
# 11  17.000000    5.000000    18.333333    1.666667    0.333333       0.333333
# ..        ...         ...          ...         ...         ...            ...
# 9    9.333333    2.333333    18.033333    0.666667    0.000000       0.000000
# 10   9.666667    2.333333    18.566667    1.000000    0.000000       0.000000
# 11  10.333333    2.333333    17.633333    0.333333    0.333333       0.333333
# 12   8.666667    2.333333    15.866667    0.666667    0.333333       0.333333
# 13  13.000000    3.333333    16.266667    0.666667    0.333333       0.333333
#
# [3956 rows x 38 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-11-01']
    test = data[data["date"] > '2022-09-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.9803921568627451

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 192        0          0 2022-09-04                  Arsenal   Manchester Utd
# 193        1          1 2022-09-18                  Arsenal        Brentford
# 194        1          1 2022-10-01                  Arsenal        Tottenham
# 195        1          1 2022-10-09                  Arsenal        Liverpool
# 196        1          1 2022-10-16                  Arsenal     Leeds United
# ...      ...        ...        ...                      ...              ...
# 3951       0          0 2022-10-08  Wolverhampton Wanderers          Chelsea
# 3952       1          1 2022-10-15  Wolverhampton Wanderers  Nott'ham Forest
# 3953       0          0 2022-10-18  Wolverhampton Wanderers   Crystal Palace
# 3954       0          0 2022-10-23  Wolverhampton Wanderers   Leicester City
# 3955       0          0 2022-10-29  Wolverhampton Wanderers        Brentford
#
#      result
# 192       L
# 193       W
# 194       W
# 195       W
# 196       W
# ...     ...
# 3951      L
# 3952      W
# 3953      L
# 3954      L
# 3955      D
#
# [152 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton", 
    "Manchester United": "Manchester Utd", 
    "Newcastle United": "Newcastle Utd", 
    "Tottenham Hotspur": "Tottenham", 
    "West Ham United": "West Ham", 
    "Wolverhampton Wanderers": "Wolves"
} 

mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            0 2022-09-04                  Arsenal
# 1           1            1 2022-09-18                  Arsenal
# 2           1            1 2022-10-01                  Arsenal
# 3           1            1 2022-10-09                  Arsenal
# 4           1            1 2022-10-16                  Arsenal
# ..        ...          ...        ...                      ...
# 139         0            0 2022-10-08  Wolverhampton Wanderers
# 140         1            1 2022-10-15  Wolverhampton Wanderers
# 141         0            0 2022-10-18  Wolverhampton Wanderers
# 142         0            0 2022-10-23  Wolverhampton Wanderers
# 143         0            0 2022-10-29  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Manchester Utd        L    Arsenal         1            1
# 1          Brentford        W    Arsenal         0            0
# 2          Tottenham        W    Arsenal         0            0
# 3          Liverpool        W    Arsenal         0            0
# 4       Leeds United        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 139          Chelsea        L     Wolves         1            1
# 140  Nott'ham Forest        W     Wolves         0            0
# 141   Crystal Palace        L     Wolves         1            1
# 142   Leicester City        L     Wolves         1            1
# 143        Brentford        D     Wolves         0            0
#
#                 team_y opponent_y result_y         new_team_y
# 0    Manchester United    Arsenal        W     Manchester Utd
# 1            Brentford    Arsenal        L          Brentford
# 2    Tottenham Hotspur    Arsenal        L          Tottenham
# 3            Liverpool    Arsenal        L          Liverpool
# 4         Leeds United    Arsenal        L       Leeds United
# ..                 ...        ...      ...                ...
# 139            Chelsea     Wolves        W            Chelsea
# 140  Nottingham Forest     Wolves        L  Nottingham Forest
# 141     Crystal Palace     Wolves        W     Crystal Palace
# 142     Leicester City     Wolves        W     Leicester City
# 143          Brentford     Wolves        D          Brentford
#
# [144 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    50
# 0     1
# Name: actual_x, dtype: int64

# %%
74/122
# Out:
# 0.6065573770491803

# %%
matches.columns
# Out:
# Index(['date', 'time', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt',
#        'season', 'team', 'target', 'venue_code', 'opp_code', 'hour',
#        'day_code'],
#       dtype='object')

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            0 2022-09-04                  Arsenal
# 1           1            1 2022-09-18                  Arsenal
# 2           1            1 2022-10-01                  Arsenal
# 3           1            1 2022-10-09                  Arsenal
# 4           1            1 2022-10-16                  Arsenal
# ..        ...          ...        ...                      ...
# 139         0            0 2022-10-08  Wolverhampton Wanderers
# 140         1            1 2022-10-15  Wolverhampton Wanderers
# 141         0            0 2022-10-18  Wolverhampton Wanderers
# 142         0            0 2022-10-23  Wolverhampton Wanderers
# 143         0            0 2022-10-29  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Manchester Utd        L    Arsenal         1            1
# 1          Brentford        W    Arsenal         0            0
# 2          Tottenham        W    Arsenal         0            0
# 3          Liverpool        W    Arsenal         0            0
# 4       Leeds United        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 139          Chelsea        L     Wolves         1            1
# 140  Nott'ham Forest        W     Wolves         0            0
# 141   Crystal Palace        L     Wolves         1            1
# 142   Leicester City        L     Wolves         1            1
# 143        Brentford        D     Wolves         0            0
#
#                 team_y opponent_y result_y         new_team_y
# 0    Manchester United    Arsenal        W     Manchester Utd
# 1            Brentford    Arsenal        L          Brentford
# 2    Tottenham Hotspur    Arsenal        L          Tottenham
# 3            Liverpool    Arsenal        L          Liverpool
# 4         Leeds United    Arsenal        L       Leeds United
# ..                 ...        ...      ...                ...
# 139            Chelsea     Wolves        W            Chelsea
# 140  Nottingham Forest     Wolves        L  Nottingham Forest
# 141     Crystal Palace     Wolves        W     Crystal Palace
# 142     Leicester City     Wolves        W     Leicester City
# 143          Brentford     Wolves        D          Brentford
#
# [144 rows x 13 columns]

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            0 2022-09-04                  Arsenal
# 1           1            1 2022-09-18                  Arsenal
# 2           1            1 2022-10-01                  Arsenal
# 3           1            1 2022-10-09                  Arsenal
# 4           1            1 2022-10-16                  Arsenal
# ..        ...          ...        ...                      ...
# 139         0            0 2022-10-08  Wolverhampton Wanderers
# 140         1            1 2022-10-15  Wolverhampton Wanderers
# 141         0            0 2022-10-18  Wolverhampton Wanderers
# 142         0            0 2022-10-23  Wolverhampton Wanderers
# 143         0            0 2022-10-29  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Manchester Utd        L    Arsenal         1            1
# 1          Brentford        W    Arsenal         0            0
# 2          Tottenham        W    Arsenal         0            0
# 3          Liverpool        W    Arsenal         0            0
# 4       Leeds United        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 139          Chelsea        L     Wolves         1            1
# 140  Nott'ham Forest        W     Wolves         0            0
# 141   Crystal Palace        L     Wolves         1            1
# 142   Leicester City        L     Wolves         1            1
# 143        Brentford        D     Wolves         0            0
#
#                 team_y opponent_y result_y         new_team_y
# 0    Manchester United    Arsenal        W     Manchester Utd
# 1            Brentford    Arsenal        L          Brentford
# 2    Tottenham Hotspur    Arsenal        L          Tottenham
# 3            Liverpool    Arsenal        L          Liverpool
# 4         Leeds United    Arsenal        L       Leeds United
# ..                 ...        ...      ...                ...
# 139            Chelsea     Wolves        W            Chelsea
# 140  Nottingham Forest     Wolves        L  Nottingham Forest
# 141     Crystal Palace     Wolves        W     Crystal Palace
# 142     Leicester City     Wolves        W     Leicester City
# 143          Brentford     Wolves        D          Brentford
#
# [144 rows x 13 columns]

# %%
merged.describe
# Out:
# <bound method NDFrame.describe of      actual_x  predicted_x       date                   team_x  \
# 0           0            0 2022-09-04                  Arsenal
# 1           1            1 2022-09-18                  Arsenal
# 2           1            1 2022-10-01                  Arsenal
# 3           1            1 2022-10-09                  Arsenal
# 4           1            1 2022-10-16                  Arsenal
# ..        ...          ...        ...                      ...
# 139         0            0 2022-10-08  Wolverhampton Wanderers
# 140         1            1 2022-10-15  Wolverhampton Wanderers
# 141         0            0 2022-10-18  Wolverhampton Wanderers
# 142         0            0 2022-10-23  Wolverhampton Wanderers
# 143         0            0 2022-10-29  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Manchester Utd        L    Arsenal         1            1
# 1          Brentford        W    Arsenal         0            0
# 2          Tottenham        W    Arsenal         0            0
# 3          Liverpool        W    Arsenal         0            0
# 4       Leeds United        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 139          Chelsea        L     Wolves         1            1
# 140  Nott'ham Forest        W     Wolves         0            0
# 141   Crystal Palace        L     Wolves         1            1
# 142   Leicester City        L     Wolves         1            1
# 143        Brentford        D     Wolves         0            0
#
#                 team_y opponent_y result_y         new_team_y
# 0    Manchester United    Arsenal        W     Manchester Utd
# 1            Brentford    Arsenal        L          Brentford
# 2    Tottenham Hotspur    Arsenal        L          Tottenham
# 3            Liverpool    Arsenal        L          Liverpool
# 4         Leeds United    Arsenal        L       Leeds United
# ..                 ...        ...      ...                ...
# 139            Chelsea     Wolves        W            Chelsea
# 140  Nottingham Forest     Wolves        L  Nottingham Forest
# 141     Crystal Palace     Wolves        W     Crystal Palace
# 142     Leicester City     Wolves        W     Leicester City
# 143          Brentford     Wolves        D          Brentford
#
# [144 rows x 13 columns]>

# %%
merged.to_csv("ultra.csv")
